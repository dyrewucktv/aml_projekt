# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(rc={'figure.figsize':(8,6)})

# %%
df = pd.read_csv('classification_performance.csv')

# %%
df
# Out:
#       dataset        method      time  accuracy  random_state  iters  product
# 0    banknote          IWLS  0.000980  0.867278           420      5     True
# 1    banknote           SGD  0.103472  0.847615           420      8     True
# 2    banknote          ADAM  0.180819  0.864020           420     10     True
# 3    banknote           LDA  0.000666  0.863996           420     -1     True
# 4    banknote           QDA  0.000273  0.869974           420     -1     True
# ..        ...           ...       ...       ...           ...    ...      ...
# 583       pc1          ADAM  0.096593  0.716339           777      6    False
# 584       pc1           LDA  0.000538  0.623983           777     -1    False
# 585       pc1           QDA  0.000235  0.651332           777     -1    False
# 586       pc1  DecisionTree  0.021078  0.578892           777     -1    False
# 587       pc1  RandomForest  0.341568  0.605470           777     -1    False
#
# [588 rows x 7 columns]

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(data=df[df["product"] == True], x="dataset", y="accuracy", hue="method")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title("Classification performance on product datasets")
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(data=df[df["product"] == False], x="dataset", y="accuracy", hue="method")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45)
# set title
plt.title("Classification accuracy for non-product datasets")
plt.show()

# %%
df_true = df[df["product"] == True]

# %%
df_true.groupby(["dataset", "method"]).agg({"accuracy": [("mean_accuracy", "mean"), ("std_accuracy", "std")]}).sort_values(by=["dataset", ("accuracy", "mean_accuracy")], ascending=[True, False])
# Out:
#                            accuracy
#                       mean_accuracy std_accuracy
# dataset  method
# banknote RandomForest      0.957249     0.007839
#          DecisionTree      0.945232     0.009695
#          QDA               0.871153     0.019954
#          LDA               0.865019     0.014824
#          IWLS              0.864164     0.010765
#          ADAM              0.860906     0.010982
#          SGD               0.859485     0.015621
# kin8nm   RandomForest      0.861080     0.008271
#          QDA               0.807280     0.009780
#          IWLS              0.795499     0.007684
#          ADAM              0.792986     0.010186
#          LDA               0.788103     0.011262
#          DecisionTree      0.784818     0.009158
#          SGD               0.737732     0.010718
# phoneme  RandomForest      0.872172     0.004540
#          DecisionTree      0.824929     0.008848
#          QDA               0.802470     0.005341
#          ADAM              0.775786     0.006012
#          IWLS              0.773856     0.004367
#          SGD               0.720992     0.028334
#          LDA               0.698349     0.007372

# %%
df_false = df[df["product"] == False]

# %%
# display all rows
pd.set_option('display.max_rows', None)

df_false.groupby(["dataset", "method"]).agg({"accuracy": [("mean_accuracy", "mean"), ("std_accuracy", "std")]}).sort_values(by=["dataset", ("accuracy", "mean_accuracy")], ascending=[True, False])
# Out:
#                                      accuracy
#                                 mean_accuracy std_accuracy
# dataset            method
# banknote           RandomForest      0.888426     0.013858
#                    DecisionTree      0.877964     0.014600
#                    LDA               0.866418     0.012465
#                    QDA               0.863998     0.012386
#                    SGD               0.860044     0.012000
#                    IWLS              0.854741     0.008721
#                    ADAM              0.851465     0.009423
# elevators          IWLS              0.679128     0.006585
#                    ADAM              0.679072     0.007084
#                    RandomForest      0.672565     0.005461
#                    SGD               0.654881     0.015777
#                    LDA               0.653548     0.003847
#                    QDA               0.651085     0.003783
#                    DecisionTree      0.637385     0.005072
# jm1                IWLS              0.613466     0.011449
#                    ADAM              0.612520     0.010425
#                    SGD               0.570165     0.060238
#                    QDA               0.558162     0.004654
#                    DecisionTree      0.532324     0.011940
#                    RandomForest      0.525448     0.005182
#                    LDA               0.523722     0.003510
# kdd_JapaneseVowels QDA               0.969901     0.005006
#                    RandomForest      0.969620     0.004823
#                    DecisionTree      0.948290     0.006566
#                    LDA               0.888700     0.011271
#                    IWLS              0.840715     0.007071
#                    ADAM              0.839209     0.007218
#                    SGD               0.816855     0.006612
# kin8nm             RandomForest      0.834232     0.005252
#                    QDA               0.785105     0.009296
#                    DecisionTree      0.752729     0.009689
#                    ADAM              0.729514     0.004261
#                    IWLS              0.728524     0.003917
#                    LDA               0.726633     0.005228
#                    SGD               0.707385     0.011694
# mfeat-karhunen     LDA               0.984392     0.010804
#                    QDA               0.980952     0.010446
#                    RandomForest      0.908333     0.019837
#                    DecisionTree      0.903175     0.024133
#                    ADAM              0.851720     0.011730
#                    IWLS              0.849074     0.009290
#                    SGD               0.806878     0.013256
# mfeat-zernike      QDA               0.974471     0.005067
#                    LDA               0.956481     0.016615
#                    RandomForest      0.942857     0.019603
#                    DecisionTree      0.934921     0.018103
#                    ADAM              0.874206     0.012066
#                    IWLS              0.872090     0.012006
#                    SGD               0.848545     0.021376
# pc1                ADAM              0.693598     0.054951
#                    IWLS              0.690032     0.043272
#                    QDA               0.603376     0.033878
#                    SGD               0.602204     0.171478
#                    LDA               0.585334     0.032182
#                    RandomForest      0.567742     0.032120
#                    DecisionTree      0.552324     0.031365
# phoneme            RandomForest      0.876724     0.006394
#                    DecisionTree      0.835999     0.005818
#                    QDA               0.776182     0.007378
#                    ADAM              0.749006     0.005693
#                    IWLS              0.747005     0.006073
#                    SGD               0.728906     0.021906
#                    LDA               0.681942     0.012790
